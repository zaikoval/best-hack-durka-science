# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('train.xlsx')

# %%
data.Shrt_Desc = data.Shrt_Desc.map(lambda x: x.lower())

# %%
types = np.zeros(len(data))

# %%
types[data.Shrt_Desc.str.contains('beef')] = 4
types[data.Shrt_Desc.str.contains('meat')] = 4
types[data.Shrt_Desc.str.contains('chick')] = 4
types[data.Shrt_Desc.str.contains('lamb')] = 4
types[data.Shrt_Desc.str.contains('pork')] = 4
types[data.Shrt_Desc.str.contains('turkey')] = 4
types[data.Shrt_Desc.str.contains('kfc')] = 4
types[data.Shrt_Desc.str.contains('octopus')] = 4
types[data.Shrt_Desc.str.contains('veal')] = 4
types[data.Shrt_Desc.str.contains('venison')] = 4
types[data.Shrt_Desc.str.contains('bacon')] = 4
types[data.Shrt_Desc.str.contains('ham')] = 4
types[data.Shrt_Desc.str.contains('liver')] = 4
types[data.Shrt_Desc.str.contains('chicken')] = 4
types[data.Shrt_Desc.str.contains('duck')] = 4
types[data.Shrt_Desc.str.contains('goose')] = 4
types[data.Shrt_Desc.str.contains('fish')] = 4
types[data.Shrt_Desc.str.contains('seafood')] = 4

# %%
types[data.Shrt_Desc.str.contains('vegetable')] = 5
types[data.Shrt_Desc.str.contains('fruit')] = 5
types[data.Shrt_Desc.str.contains('apple')] = 5
types[data.Shrt_Desc.str.contains('banana')] = 5
types[data.Shrt_Desc.str.contains('palm')] = 5
types[data.Shrt_Desc.str.contains('potato')] = 5
types[data.Shrt_Desc.str.contains('coconut')] = 5
types[data.Shrt_Desc.str.contains('apricot')] = 5
types[data.Shrt_Desc.str.contains('avocado')] = 5
types[data.Shrt_Desc.str.contains('bergamot')] = 5
types[data.Shrt_Desc.str.contains('pineapple')] = 5
types[data.Shrt_Desc.str.contains('palm')] = 5
types[data.Shrt_Desc.str.contains('grapefruit')] = 5
types[data.Shrt_Desc.str.contains('lime')] = 5
types[data.Shrt_Desc.str.contains('lemon')] = 5
types[data.Shrt_Desc.str.contains('loquat')] = 5
types[data.Shrt_Desc.str.contains('mango')] = 5
types[data.Shrt_Desc.str.contains('melon')] = 5
types[data.Shrt_Desc.str.contains('nectarine')] = 5
types[data.Shrt_Desc.str.contains('orange')] = 5
types[data.Shrt_Desc.str.contains('papaya')] = 5
types[data.Shrt_Desc.str.contains('pear')] = 5
types[data.Shrt_Desc.str.contains('persimmon')] = 5
types[data.Shrt_Desc.str.contains('pineapple')] = 5
types[data.Shrt_Desc.str.contains('pomelo')] = 5
types[data.Shrt_Desc.str.contains('plum')] = 5

# %%
types[data.Shrt_Desc.str.contains('muffins')] = 1
types[data.Shrt_Desc.str.contains('baking')] = 1
types[data.Shrt_Desc.str.contains('pudding')] = 1
types[data.Shrt_Desc.str.contains('phyllo')] = 1
types[data.Shrt_Desc.str.contains('wheat')] = 1
types[data.Shrt_Desc.str.contains('cookies')] = 1
types[data.Shrt_Desc.str.contains('pizza')] = 1

# %%
types[data.Shrt_Desc.str.contains('vinegar')] = 2
types[data.Shrt_Desc.str.contains('water')] = 2
types[data.Shrt_Desc.str.contains('alcohol')] = 2
types[data.Shrt_Desc.str.contains('coffee')] = 2
types[data.Shrt_Desc.str.contains('grease')] = 2
types[data.Shrt_Desc.str.contains('juice')] = 2
types[data.Shrt_Desc.str.contains('oil')] = 2
types[data.Shrt_Desc.str.contains('syrup')] = 2
types[data.Shrt_Desc.str.contains('soup')] = 2
types[data.Shrt_Desc.str.contains('tea')] = 2

# %%
types[data.Shrt_Desc.str.contains('cheese')] = 3
types[data.Shrt_Desc.str.contains('cream')] = 3
types[data.Shrt_Desc.str.contains('butter')] = 3
types[data.Shrt_Desc.str.contains('buttermilk')] = 3
types[data.Shrt_Desc.str.contains('cottage cheese')] = 3
types[data.Shrt_Desc.str.contains('creamery')] = 3
types[data.Shrt_Desc.str.contains('yogurt')] = 3
types[data.Shrt_Desc.str.contains('whey')] = 3
types[data.Shrt_Desc.str.contains('sour cream')] = 3
types[data.Shrt_Desc.str.contains('kefir')] = 3
types[data.Shrt_Desc.str.contains('ice cream')] = 3
types[data.Shrt_Desc.str.contains('dairy')] = 3

# %%
test_data = data[types == 0]
train = data[types != 0]

# %%
train.head()
# Out:
#                                            Shrt_Desc  Water_(g)  Energ_Kcal  \
# 0                 babyfood,crl,oatmeal,w/bananas,dry       4.70         393
# 1                              hearts of palm,canned      90.20          28
# 2  chicken,broilers or fryers,thigh,meat only,ckd...      63.89         196
# 3            pork,cured,shldr,arm picnic,ln&fat,rstd      54.73         280
# 4                                  vinegar,distilled      94.78          18
#
#    Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  \
# 0        12.00           6.00     3.90           73.40           5.2
# 1         2.52           0.62     2.04            4.62           2.4
# 2        24.06          11.09     1.56            0.00           0.0
# 3        20.43          21.35     3.51            0.00           0.0
# 4         0.00           0.00     0.02            0.04           0.0
#
#    Sugar_Tot_(g)  Calcium_(mg)     ...      Vit_K_(µg)  FA_Sat_(g)  \
# ...

# %%
typ = pd.Series(types)

# %%
vals = typ[typ != 0].index
test_vals = typ[typ == 0].index

# %%
train = data.iloc[vals, :]
train['classes'] = typ
# Out:
# C:\Anaconda_new_new\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train = train.loc[:, ['Shrt_Desc', 'classes']]

# %%
train['Shrt_Desc'] = train['Shrt_Desc'].apply(lambda x: " ".join(x.split(',')))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=2, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(train['Shrt_Desc']).toarray()
labels = train['classes']
features.shape
# Out:
# (4496, 4409)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import f1_score
from sklearn.feature_extraction.text import CountVectorizer


X_train, X_test, y_train, y_test = train_test_split(train['Shrt_Desc'], labels, test_size=0.1, random_state=17)


nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])


cross_val_score(nb, X_train, y_train, cv=10, scoring='f1_macro').mean()
# Out:
# 0.8693457637710443

# %%
from sklearn.linear_model import LogisticRegression

log_reg = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', LogisticRegression(C = 100.0, penalty = 'l1')),
              ])

cross_val_score(log_reg, X_train, y_train, cv=10, scoring='f1_macro').mean()
# Out:
# C:\Anaconda_new_new\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda_new_new\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.9868497404916937

# %%
from sklearn.ensemble import RandomForestClassifier

forest = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', RandomForestClassifier(n_estimators=1000, max_depth=20)),
              ])

cross_val_score(forest, X_train, y_train, cv=10, scoring='f1_macro').mean()
# Out:
# 0.8532669279311056

# %%
from sklearn.linear_model import SGDClassifier

sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=40, tol=None)),
               ])


cross_val_score(sgd, X_train, y_train, cv=10, scoring='f1_macro').mean()
# Out:
# 0.952393123183452

# %%
test = test_data.loc[:, 'Shrt_Desc']

# %%
sgd.fit(train['Shrt_Desc'], train['classes'])
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=Non...
#                 ('clf',
#                  SGDClassifier(alpha=0.001, average=False, class_weight=None,
#                                early_stopping=False, epsilon=0.1, eta0=0.0,
#                                fit_intercept=True, l1_ratio=0.15,
# ...

# %%
log_reg.fit(train['Shrt_Desc'], train['classes'])
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('tfidf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 ('clf',
#                  LogisticRegression(C=100.0, class_weight=None, dual=False,
# ...

# %%
data['classes'] = 0

# %%
data['classes'][train.index] = train['classes']
# Out:
# C:\Anaconda_new_new\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['classes'][test.index] = log_reg.predict(test)
# Out:
# C:\Anaconda_new_new\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.loc[:, ['Shrt_Desc', 'classes']].to_csv('train_text_classification.csv', index=False)

# %%
test = pd.read_excel('test.xlsx')

# %%
test
# Out:
#                                              Shrt_Desc  Water_(g)  \
# 0                             SILK KEY LIME SOY YOGURT      77.59
# 1                 FAST FOODS,SALAD,VEG,TOSSED,WO/DRSNG      95.51
# 2                     CUTTLEFISH,MXD SP,CKD,MOIST HEAT      61.12
# 3                      GROUND TURKEY,93% LN,7% FAT,RAW      72.63
# 4    TURKEY,RTL PARTS,ENHANCED,BREAST,MEAT ONLY,CKD...      69.99
# 5         PORK,CURED,HAM,REG (APPROX 13% FAT),CND,RSTD      60.93
# 6                         PEANUT BUTTER,SMOOTH,RED FAT       1.20
# 7      PORK,CURED,HAM -- H2O ADDED,WHL,BNLESS,LN,UNHTD      73.95
# 8             PORK,FRSH,LOIN,COUNTRY-STYLE RIBS,LN,RAW      72.84
# 9                                ICE CREAMS,STRAWBERRY      60.00
# 10   PORK,FRSH,COMP OF RTL CUTS (LOIN & SHLDR BLADE...      69.13
# 11             TEA,RTD,UNSWTND,WENDY'S,FAST FD,WO/ ICE      99.79
# 12                   PRUNES,DEHYD (LOW-MOISTURE),UNCKD       4.00
# ...

# %%
test_frame = pd.DataFrame({'Описание': test['Shrt_Desc'],
             'Pred_class': log_reg.predict(test['Shrt_Desc'])})

# %%
test_frame.to_csv('test_text_classification.csv', index=False)

# %%
test_frame
# Out:
#                                               Описание  Pred_class
# 0                             SILK KEY LIME SOY YOGURT         3.0
# 1                 FAST FOODS,SALAD,VEG,TOSSED,WO/DRSNG         4.0
# 2                     CUTTLEFISH,MXD SP,CKD,MOIST HEAT         4.0
# 3                      GROUND TURKEY,93% LN,7% FAT,RAW         4.0
# 4    TURKEY,RTL PARTS,ENHANCED,BREAST,MEAT ONLY,CKD...         4.0
# 5         PORK,CURED,HAM,REG (APPROX 13% FAT),CND,RSTD         4.0
# 6                         PEANUT BUTTER,SMOOTH,RED FAT         3.0
# 7      PORK,CURED,HAM -- H2O ADDED,WHL,BNLESS,LN,UNHTD         4.0
# 8             PORK,FRSH,LOIN,COUNTRY-STYLE RIBS,LN,RAW         4.0
# 9                                ICE CREAMS,STRAWBERRY         3.0
# 10   PORK,FRSH,COMP OF RTL CUTS (LOIN & SHLDR BLADE...         4.0
# 11             TEA,RTD,UNSWTND,WENDY'S,FAST FD,WO/ ICE         2.0
# 12                   PRUNES,DEHYD (LOW-MOISTURE),UNCKD         4.0
# ...
